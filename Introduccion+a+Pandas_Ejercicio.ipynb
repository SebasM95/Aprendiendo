# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasM95/Aprendiendo/blob/main/Introduccion%2Ba%2BPandas_Ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar pandas
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Opcional: usa el pd.set_option() para mostrar todas las filas de un dataframe por defecto
db_bestseller=pd.read_csv('/content/drive/MyDrive/bestsellers+with+categories - bestsellers+with+categories.csv')
db_bestseller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %% [markdown]
# # Crear un DataFrame

# %%
# leer el archivo csv "bestsellers with categories" (data sobre los 50 libros más vendidos de Amazon de 2009 a 2019.)
db_bestseller=pd.read_csv('/content/drive/MyDrive/bestsellers+with+categories - bestsellers+with+categories.csv')

# %%
# acceder al atributo shape
db_bestseller.shape
# Out:
# (550, 7)

# %%
# encontrar el tipo de data de cada columna
type(db_bestseller)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Mostrar un DataFrame

# %%
# mostrar primeras 5 filas de un dataframe
db_bestseller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# encontrar valores estadisticos de un dataframe (mean, std, min, max)
db_bestseller.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Agregar una nueva Columna

# %%
# Tu tarea es crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4
# 1.importar numpy y crear 550 numeros random enteros entre 1 y 4
aleatorio=np.random.randint(1, 4, size=550)
# 2.agregar nueva columna 'Critic Rating' al dataframe usando los numeros random creados
db_bestseller['Critic Rating']=aleatorio
db_bestseller
# Obs: Los numeros aleatorios en la columna 'Critic Rating' seran diferentes entre tu solucion y la mia, pero vamos a concetrarnos en el codigo en esta seccion.
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic Rating
# 0                3
# 1                3
# 2                1
# 3                2
# 4                3
# ..             ...
# 545              2
# 546              1
# 547              2
# 548              2
# 549              3
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
db_bestseller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              3
# 1              3
# 2              1
# 3              2
# 4              3

# %% [markdown]
# # Atributos, Metodos y Funciones Basicas

# %%
# acceder al atributo "columns"
db_bestseller.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic Rating'],
#       dtype='object')

# %% [markdown]
# # Seleccionar 2 o Mas Columnas de un Dataframe

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" Luego actualizar el dataframe
#del db_bestseller['Critic Rating']
db_bestseller.insert(3, 'Critic Rating',aleatorio)
db_bestseller
# Tip: Copiar y pegar los nombres de columna obtenidos con el atributo "columns" y reordenar los elementos usando [[]]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              3    17350      8
# 1                Stephen King          4.6              3     2052     22
# 2          Jordan B. Peterson          4.7              1    18979     15
# 3               George Orwell          4.7              2    21424      6
# 4    National Geographic Kids          4.8              3     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9              2     9413      8
# 546               Jen Sincero          4.7              1    14331      8
# 547               Jen Sincero          4.7              2    14331      8
# 548               Jen Sincero          4.7              2    14331      8
# 549               Jen Sincero          4.7              3    14331      8
#
#      Year        Genre
# 0    2016  Non Fiction
# 1    2011      Fiction
# 2    2018  Non Fiction
# 3    2017      Fiction
# 4    2019  Non Fiction
# ..    ...          ...
# 545  2019      Fiction
# 546  2016  Non Fiction
# 547  2017  Non Fiction
# 548  2018  Non Fiction
# 549  2019  Non Fiction
#
# [550 rows x 8 columns]

# %%
# mostrar 5 primeras filas
db_bestseller.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Critic Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              3    17350      8  2016
# 1              Stephen King          4.6              3     2052     22  2011
# 2        Jordan B. Peterson          4.7              1    18979     15  2018
# 3             George Orwell          4.7              2    21424      6  2017
# 4  National Geographic Kids          4.8              3     7665     12  2019
#
#          Genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction
# 4  Non Fiction

# %% [markdown]
# # Operaciones en Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rating = (User Rating + Critic Rating)/2
db_bestseller['Average Rating']=(db_bestseller['User Rating']+db_bestseller['Critic Rating'])/2
db_bestseller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              3    17350      8
# 1                Stephen King          4.6              3     2052     22
# 2          Jordan B. Peterson          4.7              1    18979     15
# 3               George Orwell          4.7              2    21424      6
# 4    National Geographic Kids          4.8              3     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9              2     9413      8
# 546               Jen Sincero          4.7              1    14331      8
# 547               Jen Sincero          4.7              2    14331      8
# 548               Jen Sincero          4.7              2    14331      8
# 549               Jen Sincero          4.7              3    14331      8
#
#      Year        Genre  Average Rating
# 0    2016  Non Fiction            3.85
# 1    2011      Fiction            3.80
# 2    2018  Non Fiction            2.85
# 3    2017      Fiction            3.35
# 4    2019  Non Fiction            3.90
# ..    ...          ...             ...
# 545  2019      Fiction            3.45
# 546  2016  Non Fiction            2.85
# 547  2017  Non Fiction            3.35
# 548  2018  Non Fiction            3.35
# 549  2019  Non Fiction            3.85
#
# [550 rows x 9 columns]

# %%
# usar la funcion "round" para redondear los valores del dataframe a 1 decimal y actualizar el dataframe
db_bestseller.round(1)
db_bestseller

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa
db_bestseller['Genre'].value_counts()
# Out:
# Genre
# Non Fiction    310
# Fiction        240
# Name: count, dtype: int64

# %% [markdown]
# # Renombrar Columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
db_bestseller1=db_bestseller = db_bestseller.rename(columns={'User Rating': 'UR',
                                             'Critic Rating': 'CR',
                                             'Average Rating': 'AR'})
db_bestseller
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR  Reviews  Price  Year        Genre  \
# 0                    JJ Smith  4.7   3    17350      8  2016  Non Fiction
# 1                Stephen King  4.6   3     2052     22  2011      Fiction
# 2          Jordan B. Peterson  4.7   1    18979     15  2018  Non Fiction
# 3               George Orwell  4.7   2    21424      6  2017      Fiction
# 4    National Geographic Kids  4.8   3     7665     12  2019  Non Fiction
# ..                        ...  ...  ..      ...    ...   ...          ...
# 545               Jeff Kinney  4.9   2     9413      8  2019      Fiction
# 546               Jen Sincero  4.7   1    14331      8  2016  Non Fiction
# 547               Jen Sincero  4.7   2    14331      8  2017  Non Fiction
# 548               Jen Sincero  4.7   2    14331      8  2018  Non Fiction
# 549               Jen Sincero  4.7   3    14331      8  2019  Non Fiction
#
#        AR
# 0    3.85
# 1    3.80
# 2    2.85
# 3    3.35
# 4    3.90
# ..    ...
# 545  3.45
# 546  2.85
# 547  3.35
# 548  3.35
# 549  3.85
#
# [550 rows x 9 columns]

# %%
# mostrar 5 primeras filas
db_bestseller1.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  CR  Reviews  Price  Year        Genre    AR
# 0                  JJ Smith  4.7   3    17350      8  2016  Non Fiction  3.85
# 1              Stephen King  4.6   3     2052     22  2011      Fiction  3.80
# 2        Jordan B. Peterson  4.7   1    18979     15  2018  Non Fiction  2.85
# 3             George Orwell  4.7   2    21424      6  2017      Fiction  3.35
# 4  National Geographic Kids  4.8   3     7665     12  2019  Non Fiction  3.90

# %%
# seleccionar solo columnas "Name", "Author", "UR", "CR", "AR" y "Year" y actualizar el dataframe
db_bestseller_orden= db_bestseller1.loc[:, ['Name', 'Author', 'UR', 'CR', 'AR', 'Year']]
db_bestseller_orden
# Out:
#                                                   Name                Author  \
# 40            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 82   Dog Man: A Tale of Two Kitties: From the Creat...            Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...            Dav Pilkey
# 147  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 153  Harry Potter and the Chamber of Secrets: The I...          J.K. Rowling
# ..                                                 ...                   ...
# 22                                           Allegiant         Veronica Roth
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 132                         Go Set a Watchman: A Novel            Harper Lee
# 353                                 The Casual Vacancy          J.K. Rowling
#
#       UR  CR    AR  Year
# 40   4.9   3  3.95  2017
# 82   4.9   3  3.95  2017
# 85   4.9   3  3.95  2019
# 147  4.9   3  3.95  2013
# 153  4.9   3  3.95  2016
# ..   ...  ..   ...   ...
# 22   3.9   1  2.45  2013
# 106  3.8   1  2.40  2012
# 107  3.8   1  2.40  2013
# 132  3.6   3  3.30  2015
# 353  3.3   2  2.65  2012
#
# [550 rows x 6 columns]

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
db_bestseller_orden.sort_values(['UR','CR'],ascending=False,
                           inplace=True)
db_bestseller_orden
# Out:
#                                                   Name                Author  \
# 40            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 82   Dog Man: A Tale of Two Kitties: From the Creat...            Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...            Dav Pilkey
# 147  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
# 153  Harry Potter and the Chamber of Secrets: The I...          J.K. Rowling
# ..                                                 ...                   ...
# 22                                           Allegiant         Veronica Roth
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...             E L James
# 132                         Go Set a Watchman: A Novel            Harper Lee
# 353                                 The Casual Vacancy          J.K. Rowling
#
#       UR  CR    AR  Year
# 40   4.9   3  3.95  2017
# 82   4.9   3  3.95  2017
# 85   4.9   3  3.95  2019
# 147  4.9   3  3.95  2013
# 153  4.9   3  3.95  2016
# ..   ...  ..   ...   ...
# 22   3.9   1  2.45  2013
# 106  3.8   1  2.40  2012
# 107  3.8   1  2.40  2013
# 132  3.6   3  3.30  2015
# 353  3.3   2  2.65  2012
#
# [550 rows x 6 columns]
